# %%
# Initialisation
# Import packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

# Import ML packages
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

# Import Google Drive to allow access to data
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check TensorFlow Version
print(tf.__version__)

# Initialise variable that defines the location of dataset
dataLoc = '[REDACTED]'

# Read in dataset
df = pd.read_csv(dataLoc)

# Change the frame variable from numerical integer to categorical
df['Frame'] = df['Frame'].astype('category')
df['BattCells'] = df['BattCells'].astype('category')

# Drop Weight and Remaining Load columns
df = df.drop(['Weight','RemLoad'], axis=1)
df = df.drop(columns = ['NLC','NLV','LimCurrent','InternalR','Blades','ESCCells'])

# Separate categorical variables into a boolean definition
# df = pd.get_dummies(df, columns = ['Frame'],prefix = '', prefix_sep = '')
# df = pd.get_dummies(df, columns = ['BattCells'],prefix = '', prefix_sep = '')

# Visual check of the dataframe to ensure that it is the same as what we are after
df.tail()

# Set the training and test datasets
train_data = df.sample(frac = 0.8, random_state = 0)
test_data = df.drop(train_data.index)

# Check Data Types
df.dtypes
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 2.14.0
# Frame            category
# KV                  int64
# motDiam             int64
# propDiam            int64
# propPitch           int64
# ESCCurrent          int64
# BattCells        category
# BattCap             int64
# BattDischarge       int64
# Endurance         float64
# Range             float64
# MaxSpeed          float64
# MTOW              float64
# dtype: object

# %%
# Define a function to extract output variables
def outputConfigure(data):
    outFrame = data.pop('Frame')
    outFrame = np.array(outFrame)
    outKV = data.pop('KV')
    outKV = np.array(outKV)
    outMotDiam = data.pop('motDiam')
    outMotDiam = np.array(outMotDiam)
    outPropDiam = data.pop('propDiam')
    outPropDiam = np.array(outPropDiam)
    outPropPitch = data.pop('propPitch')
    outPropPitch = np.array(outPropPitch)
    outESCCurrent = data.pop('ESCCurrent')
    outESCCurrent = np.array(outESCCurrent)
    outBattCells = data.pop('BattCells')
    outBattCells = np.array(outBattCells)
    outBattCap = data.pop('BattCap')
    outBattCap = np.array(outBattCap)
    outBattDischarge = data.pop('BattDischarge')
    outBattDischage = np.array(outBattDischarge)

    return outFrame, outKV, outMotDiam, outPropDiam, outPropPitch, outESCCurrent, outBattCells, outBattCap, outBattDischarge

# Define a function to normalise input data
def normalise(var):
    return (var - trainStats['mean'])/trainStats['std']

# %%
# Load data for the model
trainFeatures = train_data.copy()
testFeatures = test_data.copy()

# Drop input variables
trainFeatures = trainFeatures.drop(columns = ['MTOW','Range','Endurance','MaxSpeed'])
testFeatures = testFeatures.drop(columns = ['MTOW','Range','Endurance','MaxSpeed'])

# Remove all non-input variables
trainFeaturesSubs = train_data[['MTOW','Range','Endurance','MaxSpeed']]
testFeaturesSubs = test_data[['MTOW','Range','Endurance','MaxSpeed']]

# %%
# Get data metrics
trainStats = trainFeaturesSubs.describe()
trainStats = trainStats.T
print(trainStats)
# Out:
#              count       mean       std   min    25%    50%    75%    max
# MTOW       41317.0   1.528431  0.683310  0.40   1.02   1.42   1.92   3.87
# Range      41317.0   5.058426  2.125099  0.00   3.54   4.67   6.22  16.35
# Endurance  41317.0   9.354633  4.890360  1.42   5.68   8.46  12.00  38.08
# MaxSpeed   41317.0  18.572108  6.962373  0.00  13.30  16.90  23.40  40.70

# %%
# Normalise training and test data
normTrainIn = np.array(normalise(trainFeaturesSubs))
normTestIn = np.array(normalise(testFeaturesSubs))

# Acquire Output Data for train and test data
trainOut = outputConfigure(trainFeatures)
testOut = outputConfigure(testFeatures)

# %%
# Define the model construction and layer use

def modelBuild():

    inputLayer = Input(shape=(len(trainFeaturesSubs.columns),))
    # Run Layer and define output for Frame Size (Cat)
    FSOut = Dense(9, activation = 'softmax', name = 'FSOut')(inputLayer)

    # Run Layers for KV (Reg)
    denseKV1 = Dense(units = '64', activation = 'relu')(inputLayer)
    denseKV2 = Dense(units = '64', activation = 'relu')(denseKV1)
    denseKV3 = Dense(units = '64', activation = 'relu')(denseKV2)
    # Define Output for KV
    KVOut = Dense(units = '1', name = 'KVOut')(denseKV3)

    # Run Layers for Motor Diameter (Reg)
    denseMD1 = Dense(units = '64', activation = 'relu')(inputLayer)
    denseMD2 = Dense(units = '64', activation = 'relu')(denseMD1)
    # Define Output for KV
    MDOut = Dense(units = '1', name = 'MDOut')(denseMD2)

    # Run Layers for Propeller Diameter (Reg)
    densePD1 = Dense(units = '64', activation = 'relu')(inputLayer)
    densePD2 = Dense(units = '64', activation = 'relu')(densePD1)
    densePD3 = Dense(units = '64', activation = 'relu')(densePD2)
    # Define Output for KV
    PDOut = Dense(units = '1', name = 'PDOut')(densePD3)

    # Run Layers for Propeller Pitch (Reg)
    densePP1 = Dense(units = '64', activation = 'relu')(inputLayer)
    densePP2 = Dense(units = '64', activation = 'relu')(densePP1)
    densePP3 = Dense(units = '64', activation = 'relu')(densePP2)
    # Define Output for KV
    PPOut = Dense(units = '1', name = 'PPOut')(densePP3)

    # Run Layers for ESC Current (Reg)
    denseESCC1 = Dense(units = '64', activation = 'relu')(inputLayer)
    denseESCC2 = Dense(units = '64', activation = 'relu')(denseESCC1)
    denseESCC3 = Dense(units = '64', activation = 'relu')(denseESCC2)
    # Define Output for KV
    ESCCOut = Dense(units = '1', name = 'ESCCOut')(denseESCC3)

    # Run Layers for Battery Cells (Cat)
    BCeOut = Dense(3, activation = 'softmax', name = 'BCeOut')(inputLayer)

    # Run Layers for Battery Capacity (Reg)
    denseBCa1 = Dense(units = '64', activation = 'relu')(inputLayer)
    denseBCa2 = Dense(units = '64', activation = 'relu')(denseBCa1)
    denseBCa3 = Dense(units = '64', activation = 'relu')(denseBCa2)
    # Define Output for KV
    BCaOut = Dense(units = '1', name = 'BCaOut')(denseBCa3)

    # Run Layers for Battery Discharge (Reg)
    denseBD1 = Dense(units = '64', activation = 'relu')(inputLayer)
    denseBD2 = Dense(units = '64', activation = 'relu')(denseBD1)
    denseBD3 = Dense(units = '64', activation = 'relu')(denseBD2)
    # Define Output for KV
    BDOut = Dense(units = '1', name = 'BDOut')(denseBD3)

    # Define model
    model = Model(inputs = inputLayer, outputs = [FSOut, KVOut, MDOut, PDOut, PPOut, ESCCOut, BCeOut, BCaOut, BDOut])

    return model

# %%
# Run Model Building function defined above
model = modelBuild()

# Select an optimiser
optimiser = tf.keras.optimizers.Adam(0.001)

# Compile DNN Model and define outputs and error values
model.compile(optimizer = optimiser,
              loss = {'FSOut': 'mae', 'KVOut': 'mae', 'MDOut': 'mae','PDOut': 'mae','PPOut': 'mae','ESCCOut': 'mae', 'BCeOut': 'mae', 'BCaOut': 'mae', 'BDOut': 'mae'},
              metrics = {'FSOut': tf.keras.metrics.MeanAbsoluteError(),
                         'KVOut': tf.keras.metrics.MeanAbsoluteError(),
                         'MDOut': tf.keras.metrics.MeanAbsoluteError(),
                         'PDOut': tf.keras.metrics.MeanAbsoluteError(),
                         'PPOut': tf.keras.metrics.MeanAbsoluteError(),
                         'ESCCOut': tf.keras.metrics.MeanAbsoluteError(),
                         'BCeOut': tf.keras.metrics.MeanAbsoluteError(),
                         'BCaOut': tf.keras.metrics.MeanAbsoluteError(),
                         'BDOut': tf.keras.metrics.MeanAbsoluteError()})

# %%
# Train the model for 100 epochs, similar to other scripts
history = model.fit(normTrainIn,trainOut,
                    validation_split = 0.2,
                    epochs = 100)
# Out:
# Epoch 1/100
# 1033/1033 [==============================] - 14s 7ms/step - loss: 1412.0823 - FSOut_loss: 307.5799 - KVOut_loss: 551.6444 - MDOut_loss: 3.1610 - PDOut_loss: 0.4111 - PPOut_loss: 0.9566 - ESCCOut_loss: 5.7851 - BCeOut_loss: 2.3281 - BCaOut_loss: 534.6259 - BDOut_loss: 5.5888 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 551.6444 - MDOut_mean_absolute_error: 3.1610 - PDOut_mean_absolute_error: 0.4111 - PPOut_mean_absolute_error: 0.9566 - ESCCOut_mean_absolute_error: 5.7851 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 534.6259 - BDOut_mean_absolute_error: 5.5888 - val_loss: 771.1236 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 220.2586 - val_MDOut_loss: 1.5868 - val_PDOut_loss: 0.1293 - val_PPOut_loss: 0.8197 - val_ESCCOut_loss: 4.8862 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 226.8252 - val_BDOut_loss: 4.8576 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 220.2586 - val_MDOut_mean_absolute_error: 1.5868 - val_PDOut_mean_absolute_error: 0.1293 - val_PPOut_mean_absolute_error: 0.8197 - val_ESCCOut_mean_absolute_error: 4.8862 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 226.8252 - val_BDOut_mean_absolute_error: 4.8576
# Epoch 2/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 732.4570 - FSOut_loss: 307.5799 - KVOut_loss: 212.2619 - MDOut_loss: 1.5544 - PDOut_loss: 0.0881 - PPOut_loss: 0.8018 - ESCCOut_loss: 4.8829 - BCeOut_loss: 2.3281 - BCaOut_loss: 198.1194 - BDOut_loss: 4.8395 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 212.2619 - MDOut_mean_absolute_error: 1.5544 - PDOut_mean_absolute_error: 0.0881 - PPOut_mean_absolute_error: 0.8018 - ESCCOut_mean_absolute_error: 4.8829 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 198.1194 - BDOut_mean_absolute_error: 4.8395 - val_loss: 711.2131 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 202.9302 - val_MDOut_loss: 1.5194 - val_PDOut_loss: 0.1093 - val_PPOut_loss: 0.8060 - val_ESCCOut_loss: 4.8589 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 184.4133 - val_BDOut_loss: 4.8162 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 202.9302 - val_MDOut_mean_absolute_error: 1.5194 - val_PDOut_mean_absolute_error: 0.1093 - val_PPOut_mean_absolute_error: 0.8060 - val_ESCCOut_mean_absolute_error: 4.8589 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 184.4133 - val_BDOut_mean_absolute_error: 4.8162
# Epoch 3/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 701.5836 - FSOut_loss: 307.5799 - KVOut_loss: 202.8186 - MDOut_loss: 1.5118 - PDOut_loss: 0.0771 - PPOut_loss: 0.7806 - ESCCOut_loss: 4.8080 - BCeOut_loss: 2.3281 - BCaOut_loss: 176.9048 - BDOut_loss: 4.7738 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 202.8186 - MDOut_mean_absolute_error: 1.5118 - PDOut_mean_absolute_error: 0.0771 - PPOut_mean_absolute_error: 0.7806 - ESCCOut_mean_absolute_error: 4.8080 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 176.9048 - BDOut_mean_absolute_error: 4.7738 - val_loss: 697.1544 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 198.9982 - val_MDOut_loss: 1.4996 - val_PDOut_loss: 0.0613 - val_PPOut_loss: 0.7820 - val_ESCCOut_loss: 4.7695 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 174.5208 - val_BDOut_loss: 4.7628 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 198.9982 - val_MDOut_mean_absolute_error: 1.4996 - val_PDOut_mean_absolute_error: 0.0613 - val_PPOut_mean_absolute_error: 0.7820 - val_ESCCOut_mean_absolute_error: 4.7695 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 174.5208 - val_BDOut_mean_absolute_error: 4.7628
# Epoch 4/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 689.4460 - FSOut_loss: 307.5799 - KVOut_loss: 199.1617 - MDOut_loss: 1.4915 - PDOut_loss: 0.0715 - PPOut_loss: 0.7640 - ESCCOut_loss: 4.7505 - BCeOut_loss: 2.3281 - BCaOut_loss: 168.5598 - BDOut_loss: 4.7376 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 199.1617 - MDOut_mean_absolute_error: 1.4915 - PDOut_mean_absolute_error: 0.0715 - PPOut_mean_absolute_error: 0.7640 - ESCCOut_mean_absolute_error: 4.7505 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 168.5598 - BDOut_mean_absolute_error: 4.7376 - val_loss: 687.5240 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 194.9848 - val_MDOut_loss: 1.4750 - val_PDOut_loss: 0.0852 - val_PPOut_loss: 0.7569 - val_ESCCOut_loss: 4.7503 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 168.9791 - val_BDOut_loss: 4.7329 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 194.9848 - val_MDOut_mean_absolute_error: 1.4750 - val_PDOut_mean_absolute_error: 0.0852 - val_PPOut_mean_absolute_error: 0.7569 - val_ESCCOut_mean_absolute_error: 4.7503 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 168.9791 - val_BDOut_mean_absolute_error: 4.7329
# Epoch 5/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 682.1254 - FSOut_loss: 307.5799 - KVOut_loss: 197.3966 - MDOut_loss: 1.4859 - PDOut_loss: 0.0664 - PPOut_loss: 0.7565 - ESCCOut_loss: 4.7004 - BCeOut_loss: 2.3281 - BCaOut_loss: 163.1393 - BDOut_loss: 4.6712 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 197.3966 - MDOut_mean_absolute_error: 1.4859 - PDOut_mean_absolute_error: 0.0664 - PPOut_mean_absolute_error: 0.7565 - ESCCOut_mean_absolute_error: 4.7004 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 163.1393 - BDOut_mean_absolute_error: 4.6712 - val_loss: 679.2242 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 195.3717 - val_MDOut_loss: 1.4867 - val_PDOut_loss: 0.0707 - val_PPOut_loss: 0.7565 - val_ESCCOut_loss: 4.7584 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 160.3065 - val_BDOut_loss: 4.7139 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 195.3717 - val_MDOut_mean_absolute_error: 1.4867 - val_PDOut_mean_absolute_error: 0.0707 - val_PPOut_mean_absolute_error: 0.7565 - val_ESCCOut_mean_absolute_error: 4.7584 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 160.3065 - val_BDOut_mean_absolute_error: 4.7139
# Epoch 6/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 676.6611 - FSOut_loss: 307.5799 - KVOut_loss: 196.1317 - MDOut_loss: 1.4759 - PDOut_loss: 0.0664 - PPOut_loss: 0.7475 - ESCCOut_loss: 4.6530 - BCeOut_loss: 2.3281 - BCaOut_loss: 159.0607 - BDOut_loss: 4.6174 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 196.1317 - MDOut_mean_absolute_error: 1.4759 - PDOut_mean_absolute_error: 0.0664 - PPOut_mean_absolute_error: 0.7475 - ESCCOut_mean_absolute_error: 4.6530 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 159.0607 - BDOut_mean_absolute_error: 4.6174 - val_loss: 675.6813 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 193.8198 - val_MDOut_loss: 1.4616 - val_PDOut_loss: 0.0622 - val_PPOut_loss: 0.7372 - val_ESCCOut_loss: 4.6972 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 158.5242 - val_BDOut_loss: 4.6189 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 193.8198 - val_MDOut_mean_absolute_error: 1.4616 - val_PDOut_mean_absolute_error: 0.0622 - val_PPOut_mean_absolute_error: 0.7372 - val_ESCCOut_mean_absolute_error: 4.6972 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 158.5242 - val_BDOut_mean_absolute_error: 4.6189
# Epoch 7/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 672.4492 - FSOut_loss: 307.5799 - KVOut_loss: 195.3038 - MDOut_loss: 1.4653 - PDOut_loss: 0.0616 - PPOut_loss: 0.7396 - ESCCOut_loss: 4.6292 - BCeOut_loss: 2.3281 - BCaOut_loss: 155.7618 - BDOut_loss: 4.5789 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 195.3038 - MDOut_mean_absolute_error: 1.4653 - PDOut_mean_absolute_error: 0.0616 - PPOut_mean_absolute_error: 0.7396 - ESCCOut_mean_absolute_error: 4.6292 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 155.7618 - BDOut_mean_absolute_error: 4.5789 - val_loss: 669.2701 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 192.0151 - val_MDOut_loss: 1.4332 - val_PDOut_loss: 0.0571 - val_PPOut_loss: 0.7326 - val_ESCCOut_loss: 4.6158 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 154.0561 - val_BDOut_loss: 4.6006 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 192.0151 - val_MDOut_mean_absolute_error: 1.4332 - val_PDOut_mean_absolute_error: 0.0571 - val_PPOut_mean_absolute_error: 0.7326 - val_ESCCOut_mean_absolute_error: 4.6158 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 154.0561 - val_BDOut_mean_absolute_error: 4.6006
# Epoch 8/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 669.1740 - FSOut_loss: 307.5799 - KVOut_loss: 194.5528 - MDOut_loss: 1.4603 - PDOut_loss: 0.0616 - PPOut_loss: 0.7333 - ESCCOut_loss: 4.6030 - BCeOut_loss: 2.3281 - BCaOut_loss: 153.3097 - BDOut_loss: 4.5444 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 194.5528 - MDOut_mean_absolute_error: 1.4603 - PDOut_mean_absolute_error: 0.0616 - PPOut_mean_absolute_error: 0.7333 - ESCCOut_mean_absolute_error: 4.6030 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 153.3097 - BDOut_mean_absolute_error: 4.5444 - val_loss: 667.7161 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 190.9889 - val_MDOut_loss: 1.4538 - val_PDOut_loss: 0.0689 - val_PPOut_loss: 0.7252 - val_ESCCOut_loss: 4.6489 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 153.4819 - val_BDOut_loss: 4.5885 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 190.9889 - val_MDOut_mean_absolute_error: 1.4538 - val_PDOut_mean_absolute_error: 0.0689 - val_PPOut_mean_absolute_error: 0.7252 - val_ESCCOut_mean_absolute_error: 4.6489 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 153.4819 - val_BDOut_mean_absolute_error: 4.5885
# Epoch 9/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 666.8361 - FSOut_loss: 307.5799 - KVOut_loss: 193.7106 - MDOut_loss: 1.4547 - PDOut_loss: 0.0592 - PPOut_loss: 0.7308 - ESCCOut_loss: 4.5921 - BCeOut_loss: 2.3281 - BCaOut_loss: 151.8705 - BDOut_loss: 4.5090 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 193.7106 - MDOut_mean_absolute_error: 1.4547 - PDOut_mean_absolute_error: 0.0592 - PPOut_mean_absolute_error: 0.7308 - ESCCOut_mean_absolute_error: 4.5921 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 151.8705 - BDOut_mean_absolute_error: 4.5090 - val_loss: 664.2409 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 190.9188 - val_MDOut_loss: 1.4714 - val_PDOut_loss: 0.0727 - val_PPOut_loss: 0.7173 - val_ESCCOut_loss: 4.5876 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 150.1077 - val_BDOut_loss: 4.6054 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 190.9188 - val_MDOut_mean_absolute_error: 1.4714 - val_PDOut_mean_absolute_error: 0.0727 - val_PPOut_mean_absolute_error: 0.7173 - val_ESCCOut_mean_absolute_error: 4.5876 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 150.1077 - val_BDOut_mean_absolute_error: 4.6054
# Epoch 10/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 664.2770 - FSOut_loss: 307.5799 - KVOut_loss: 193.0070 - MDOut_loss: 1.4560 - PDOut_loss: 0.0590 - PPOut_loss: 0.7235 - ESCCOut_loss: 4.5586 - BCeOut_loss: 2.3281 - BCaOut_loss: 150.0618 - BDOut_loss: 4.5019 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 193.0070 - MDOut_mean_absolute_error: 1.4560 - PDOut_mean_absolute_error: 0.0590 - PPOut_mean_absolute_error: 0.7235 - ESCCOut_mean_absolute_error: 4.5586 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 150.0618 - BDOut_mean_absolute_error: 4.5019 - val_loss: 663.1260 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 190.4145 - val_MDOut_loss: 1.4525 - val_PDOut_loss: 0.0643 - val_PPOut_loss: 0.7247 - val_ESCCOut_loss: 4.6028 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 149.5821 - val_BDOut_loss: 4.5254 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 190.4145 - val_MDOut_mean_absolute_error: 1.4525 - val_PDOut_mean_absolute_error: 0.0643 - val_PPOut_mean_absolute_error: 0.7247 - val_ESCCOut_mean_absolute_error: 4.6028 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 149.5821 - val_BDOut_mean_absolute_error: 4.5254
# Epoch 11/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 662.9541 - FSOut_loss: 307.5799 - KVOut_loss: 192.4622 - MDOut_loss: 1.4475 - PDOut_loss: 0.0565 - PPOut_loss: 0.7170 - ESCCOut_loss: 4.5518 - BCeOut_loss: 2.3281 - BCaOut_loss: 149.3241 - BDOut_loss: 4.4857 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 192.4622 - MDOut_mean_absolute_error: 1.4475 - PDOut_mean_absolute_error: 0.0565 - PPOut_mean_absolute_error: 0.7170 - ESCCOut_mean_absolute_error: 4.5518 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 149.3241 - BDOut_mean_absolute_error: 4.4857 - val_loss: 660.8315 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 188.5000 - val_MDOut_loss: 1.4237 - val_PDOut_loss: 0.0550 - val_PPOut_loss: 0.7225 - val_ESCCOut_loss: 4.5839 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 149.2722 - val_BDOut_loss: 4.5141 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 188.5000 - val_MDOut_mean_absolute_error: 1.4237 - val_PDOut_mean_absolute_error: 0.0550 - val_PPOut_mean_absolute_error: 0.7225 - val_ESCCOut_mean_absolute_error: 4.5839 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 149.2722 - val_BDOut_mean_absolute_error: 4.5141
# Epoch 12/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 661.5224 - FSOut_loss: 307.5799 - KVOut_loss: 192.1504 - MDOut_loss: 1.4486 - PDOut_loss: 0.0558 - PPOut_loss: 0.7143 - ESCCOut_loss: 4.5068 - BCeOut_loss: 2.3281 - BCaOut_loss: 148.2715 - BDOut_loss: 4.4655 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 192.1504 - MDOut_mean_absolute_error: 1.4486 - PDOut_mean_absolute_error: 0.0558 - PPOut_mean_absolute_error: 0.7143 - ESCCOut_mean_absolute_error: 4.5068 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 148.2715 - BDOut_mean_absolute_error: 4.4655 - val_loss: 660.5938 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 189.9056 - val_MDOut_loss: 1.4298 - val_PDOut_loss: 0.0541 - val_PPOut_loss: 0.7085 - val_ESCCOut_loss: 4.5606 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 147.6708 - val_BDOut_loss: 4.5048 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 189.9056 - val_MDOut_mean_absolute_error: 1.4298 - val_PDOut_mean_absolute_error: 0.0541 - val_PPOut_mean_absolute_error: 0.7085 - val_ESCCOut_mean_absolute_error: 4.5606 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 147.6708 - val_BDOut_mean_absolute_error: 4.5048
# Epoch 13/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 659.6953 - FSOut_loss: 307.5799 - KVOut_loss: 190.9981 - MDOut_loss: 1.4424 - PDOut_loss: 0.0552 - PPOut_loss: 0.7129 - ESCCOut_loss: 4.4992 - BCeOut_loss: 2.3281 - BCaOut_loss: 147.6455 - BDOut_loss: 4.4330 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 190.9981 - MDOut_mean_absolute_error: 1.4424 - PDOut_mean_absolute_error: 0.0552 - PPOut_mean_absolute_error: 0.7129 - ESCCOut_mean_absolute_error: 4.4992 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 147.6455 - BDOut_mean_absolute_error: 4.4330 - val_loss: 663.0879 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 190.4491 - val_MDOut_loss: 1.4167 - val_PDOut_loss: 0.0649 - val_PPOut_loss: 0.7283 - val_ESCCOut_loss: 4.5347 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 149.6230 - val_BDOut_loss: 4.5108 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 190.4491 - val_MDOut_mean_absolute_error: 1.4167 - val_PDOut_mean_absolute_error: 0.0649 - val_PPOut_mean_absolute_error: 0.7283 - val_ESCCOut_mean_absolute_error: 4.5347 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 149.6230 - val_BDOut_mean_absolute_error: 4.5108
# Epoch 14/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 658.9374 - FSOut_loss: 307.5799 - KVOut_loss: 191.3103 - MDOut_loss: 1.4431 - PDOut_loss: 0.0534 - PPOut_loss: 0.7079 - ESCCOut_loss: 4.4813 - BCeOut_loss: 2.3281 - BCaOut_loss: 146.6165 - BDOut_loss: 4.4161 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 191.3103 - MDOut_mean_absolute_error: 1.4431 - PDOut_mean_absolute_error: 0.0534 - PPOut_mean_absolute_error: 0.7079 - ESCCOut_mean_absolute_error: 4.4813 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 146.6165 - BDOut_mean_absolute_error: 4.4161 - val_loss: 657.7004 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 187.7901 - val_MDOut_loss: 1.4142 - val_PDOut_loss: 0.0570 - val_PPOut_loss: 0.7135 - val_ESCCOut_loss: 4.5129 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 146.9783 - val_BDOut_loss: 4.4745 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 187.7901 - val_MDOut_mean_absolute_error: 1.4142 - val_PDOut_mean_absolute_error: 0.0570 - val_PPOut_mean_absolute_error: 0.7135 - val_ESCCOut_mean_absolute_error: 4.5129 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 146.9783 - val_BDOut_mean_absolute_error: 4.4745
# Epoch 15/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 657.0882 - FSOut_loss: 307.5799 - KVOut_loss: 189.7962 - MDOut_loss: 1.4420 - PDOut_loss: 0.0539 - PPOut_loss: 0.7030 - ESCCOut_loss: 4.4693 - BCeOut_loss: 2.3281 - BCaOut_loss: 146.3165 - BDOut_loss: 4.3980 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 189.7962 - MDOut_mean_absolute_error: 1.4420 - PDOut_mean_absolute_error: 0.0539 - PPOut_mean_absolute_error: 0.7030 - ESCCOut_mean_absolute_error: 4.4693 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 146.3165 - BDOut_mean_absolute_error: 4.3980 - val_loss: 658.6967 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 187.3543 - val_MDOut_loss: 1.4324 - val_PDOut_loss: 0.0584 - val_PPOut_loss: 0.6999 - val_ESCCOut_loss: 4.4796 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 148.4528 - val_BDOut_loss: 4.4595 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 187.3543 - val_MDOut_mean_absolute_error: 1.4324 - val_PDOut_mean_absolute_error: 0.0584 - val_PPOut_mean_absolute_error: 0.6999 - val_ESCCOut_mean_absolute_error: 4.4796 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 148.4528 - val_BDOut_mean_absolute_error: 4.4595
# Epoch 16/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 656.4382 - FSOut_loss: 307.5799 - KVOut_loss: 189.5974 - MDOut_loss: 1.4367 - PDOut_loss: 0.0520 - PPOut_loss: 0.7010 - ESCCOut_loss: 4.4561 - BCeOut_loss: 2.3281 - BCaOut_loss: 145.9156 - BDOut_loss: 4.3701 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 189.5974 - MDOut_mean_absolute_error: 1.4367 - PDOut_mean_absolute_error: 0.0520 - PPOut_mean_absolute_error: 0.7010 - ESCCOut_mean_absolute_error: 4.4561 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 145.9156 - BDOut_mean_absolute_error: 4.3701 - val_loss: 661.8132 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 190.6906 - val_MDOut_loss: 1.4544 - val_PDOut_loss: 0.0447 - val_PPOut_loss: 0.7124 - val_ESCCOut_loss: 4.5089 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 148.2474 - val_BDOut_loss: 4.3951 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 190.6906 - val_MDOut_mean_absolute_error: 1.4544 - val_PDOut_mean_absolute_error: 0.0447 - val_PPOut_mean_absolute_error: 0.7124 - val_ESCCOut_mean_absolute_error: 4.5089 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 148.2474 - val_BDOut_mean_absolute_error: 4.3951
# Epoch 17/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 654.5954 - FSOut_loss: 307.5799 - KVOut_loss: 188.7716 - MDOut_loss: 1.4399 - PDOut_loss: 0.0523 - PPOut_loss: 0.6988 - ESCCOut_loss: 4.4408 - BCeOut_loss: 2.3281 - BCaOut_loss: 144.9323 - BDOut_loss: 4.3500 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 188.7716 - MDOut_mean_absolute_error: 1.4399 - PDOut_mean_absolute_error: 0.0523 - PPOut_mean_absolute_error: 0.6988 - ESCCOut_mean_absolute_error: 4.4408 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 144.9323 - BDOut_mean_absolute_error: 4.3500 - val_loss: 655.8092 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 186.9686 - val_MDOut_loss: 1.4316 - val_PDOut_loss: 0.0462 - val_PPOut_loss: 0.6996 - val_ESCCOut_loss: 4.5569 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 145.9743 - val_BDOut_loss: 4.3719 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 186.9686 - val_MDOut_mean_absolute_error: 1.4316 - val_PDOut_mean_absolute_error: 0.0462 - val_PPOut_mean_absolute_error: 0.6996 - val_ESCCOut_mean_absolute_error: 4.5569 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 145.9743 - val_BDOut_mean_absolute_error: 4.3719
# Epoch 18/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 653.3830 - FSOut_loss: 307.5799 - KVOut_loss: 188.2562 - MDOut_loss: 1.4402 - PDOut_loss: 0.0504 - PPOut_loss: 0.6933 - ESCCOut_loss: 4.4392 - BCeOut_loss: 2.3281 - BCaOut_loss: 144.2970 - BDOut_loss: 4.2973 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 188.2562 - MDOut_mean_absolute_error: 1.4402 - PDOut_mean_absolute_error: 0.0504 - PPOut_mean_absolute_error: 0.6933 - ESCCOut_mean_absolute_error: 4.4392 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 144.2970 - BDOut_mean_absolute_error: 4.2973 - val_loss: 655.2239 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 186.1316 - val_MDOut_loss: 1.4191 - val_PDOut_loss: 0.0567 - val_PPOut_loss: 0.6876 - val_ESCCOut_loss: 4.6596 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 146.1796 - val_BDOut_loss: 4.3300 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 186.1316 - val_MDOut_mean_absolute_error: 1.4191 - val_PDOut_mean_absolute_error: 0.0567 - val_PPOut_mean_absolute_error: 0.6876 - val_ESCCOut_mean_absolute_error: 4.6596 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 146.1796 - val_BDOut_mean_absolute_error: 4.3300
# Epoch 19/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 652.6837 - FSOut_loss: 307.5799 - KVOut_loss: 188.2575 - MDOut_loss: 1.4391 - PDOut_loss: 0.0509 - PPOut_loss: 0.6936 - ESCCOut_loss: 4.4329 - BCeOut_loss: 2.3281 - BCaOut_loss: 143.6338 - BDOut_loss: 4.2668 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 188.2575 - MDOut_mean_absolute_error: 1.4391 - PDOut_mean_absolute_error: 0.0509 - PPOut_mean_absolute_error: 0.6936 - ESCCOut_mean_absolute_error: 4.4329 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 143.6338 - BDOut_mean_absolute_error: 4.2668 - val_loss: 652.7658 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 185.6335 - val_MDOut_loss: 1.4165 - val_PDOut_loss: 0.0521 - val_PPOut_loss: 0.6812 - val_ESCCOut_loss: 4.4839 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 144.4200 - val_BDOut_loss: 4.3184 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 185.6335 - val_MDOut_mean_absolute_error: 1.4165 - val_PDOut_mean_absolute_error: 0.0521 - val_PPOut_mean_absolute_error: 0.6812 - val_ESCCOut_mean_absolute_error: 4.4839 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 144.4200 - val_BDOut_mean_absolute_error: 4.3184
# Epoch 20/100
# 1033/1033 [==============================] - 7s 6ms/step - loss: 651.2783 - FSOut_loss: 307.5799 - KVOut_loss: 187.5550 - MDOut_loss: 1.4305 - PDOut_loss: 0.0507 - PPOut_loss: 0.6899 - ESCCOut_loss: 4.4189 - BCeOut_loss: 2.3281 - BCaOut_loss: 142.9848 - BDOut_loss: 4.2391 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 187.5550 - MDOut_mean_absolute_error: 1.4305 - PDOut_mean_absolute_error: 0.0507 - PPOut_mean_absolute_error: 0.6899 - ESCCOut_mean_absolute_error: 4.4189 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 142.9848 - BDOut_mean_absolute_error: 4.2391 - val_loss: 651.3552 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 186.1491 - val_MDOut_loss: 1.4207 - val_PDOut_loss: 0.0508 - val_PPOut_loss: 0.6760 - val_ESCCOut_loss: 4.4368 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 142.6027 - val_BDOut_loss: 4.2595 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 186.1491 - val_MDOut_mean_absolute_error: 1.4207 - val_PDOut_mean_absolute_error: 0.0508 - val_PPOut_mean_absolute_error: 0.6760 - val_ESCCOut_mean_absolute_error: 4.4368 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 142.6027 - val_BDOut_mean_absolute_error: 4.2595
# Epoch 21/100
# 1033/1033 [==============================] - 7s 6ms/step - loss: 650.7964 - FSOut_loss: 307.5799 - KVOut_loss: 187.8844 - MDOut_loss: 1.4341 - PDOut_loss: 0.0488 - PPOut_loss: 0.6863 - ESCCOut_loss: 4.4053 - BCeOut_loss: 2.3281 - BCaOut_loss: 142.2266 - BDOut_loss: 4.2016 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 187.8844 - MDOut_mean_absolute_error: 1.4341 - PDOut_mean_absolute_error: 0.0488 - PPOut_mean_absolute_error: 0.6863 - ESCCOut_mean_absolute_error: 4.4053 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 142.2266 - BDOut_mean_absolute_error: 4.2016 - val_loss: 652.8658 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 185.1426 - val_MDOut_loss: 1.4740 - val_PDOut_loss: 0.0646 - val_PPOut_loss: 0.7021 - val_ESCCOut_loss: 4.4586 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 145.0810 - val_BDOut_loss: 4.1830 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 185.1426 - val_MDOut_mean_absolute_error: 1.4740 - val_PDOut_mean_absolute_error: 0.0646 - val_PPOut_mean_absolute_error: 0.7021 - val_ESCCOut_mean_absolute_error: 4.4586 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 145.0810 - val_BDOut_mean_absolute_error: 4.1830
# Epoch 22/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 649.1322 - FSOut_loss: 307.5799 - KVOut_loss: 187.1015 - MDOut_loss: 1.4366 - PDOut_loss: 0.0508 - PPOut_loss: 0.6864 - ESCCOut_loss: 4.3972 - BCeOut_loss: 2.3281 - BCaOut_loss: 141.3967 - BDOut_loss: 4.1536 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 187.1015 - MDOut_mean_absolute_error: 1.4366 - PDOut_mean_absolute_error: 0.0508 - PPOut_mean_absolute_error: 0.6864 - ESCCOut_mean_absolute_error: 4.3972 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 141.3967 - BDOut_mean_absolute_error: 4.1536 - val_loss: 648.3995 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 183.1239 - val_MDOut_loss: 1.4185 - val_PDOut_loss: 0.0630 - val_PPOut_loss: 0.6790 - val_ESCCOut_loss: 4.5427 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 142.4267 - val_BDOut_loss: 4.3856 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 183.1239 - val_MDOut_mean_absolute_error: 1.4185 - val_PDOut_mean_absolute_error: 0.0630 - val_PPOut_mean_absolute_error: 0.6790 - val_ESCCOut_mean_absolute_error: 4.5427 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 142.4267 - val_BDOut_mean_absolute_error: 4.3856
# Epoch 23/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 647.3441 - FSOut_loss: 307.5799 - KVOut_loss: 186.4343 - MDOut_loss: 1.4338 - PDOut_loss: 0.0489 - PPOut_loss: 0.6813 - ESCCOut_loss: 4.3937 - BCeOut_loss: 2.3281 - BCaOut_loss: 140.3186 - BDOut_loss: 4.1247 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 186.4343 - MDOut_mean_absolute_error: 1.4338 - PDOut_mean_absolute_error: 0.0489 - PPOut_mean_absolute_error: 0.6813 - ESCCOut_mean_absolute_error: 4.3937 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 140.3186 - BDOut_mean_absolute_error: 4.1247 - val_loss: 649.4079 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 183.7881 - val_MDOut_loss: 1.4167 - val_PDOut_loss: 0.0932 - val_PPOut_loss: 0.6809 - val_ESCCOut_loss: 4.4209 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 143.1087 - val_BDOut_loss: 4.1393 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 183.7881 - val_MDOut_mean_absolute_error: 1.4167 - val_PDOut_mean_absolute_error: 0.0932 - val_PPOut_mean_absolute_error: 0.6809 - val_ESCCOut_mean_absolute_error: 4.4209 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 143.1087 - val_BDOut_mean_absolute_error: 4.1393
# Epoch 24/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 646.4033 - FSOut_loss: 307.5799 - KVOut_loss: 186.2644 - MDOut_loss: 1.4283 - PDOut_loss: 0.0477 - PPOut_loss: 0.6802 - ESCCOut_loss: 4.3748 - BCeOut_loss: 2.3281 - BCaOut_loss: 139.6132 - BDOut_loss: 4.0848 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 186.2644 - MDOut_mean_absolute_error: 1.4283 - PDOut_mean_absolute_error: 0.0477 - PPOut_mean_absolute_error: 0.6802 - ESCCOut_mean_absolute_error: 4.3748 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 139.6132 - BDOut_mean_absolute_error: 4.0848 - val_loss: 646.0070 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 182.9002 - val_MDOut_loss: 1.4236 - val_PDOut_loss: 0.0485 - val_PPOut_loss: 0.6686 - val_ESCCOut_loss: 4.4943 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 140.5887 - val_BDOut_loss: 4.1230 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 182.9002 - val_MDOut_mean_absolute_error: 1.4236 - val_PDOut_mean_absolute_error: 0.0485 - val_PPOut_mean_absolute_error: 0.6686 - val_ESCCOut_mean_absolute_error: 4.4943 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 140.5887 - val_BDOut_mean_absolute_error: 4.1230
# Epoch 25/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 644.5558 - FSOut_loss: 307.5799 - KVOut_loss: 185.6835 - MDOut_loss: 1.4270 - PDOut_loss: 0.0465 - PPOut_loss: 0.6762 - ESCCOut_loss: 4.3660 - BCeOut_loss: 2.3281 - BCaOut_loss: 138.3799 - BDOut_loss: 4.0674 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 185.6835 - MDOut_mean_absolute_error: 1.4270 - PDOut_mean_absolute_error: 0.0465 - PPOut_mean_absolute_error: 0.6762 - ESCCOut_mean_absolute_error: 4.3660 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 138.3799 - BDOut_mean_absolute_error: 4.0674 - val_loss: 643.5172 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 182.6492 - val_MDOut_loss: 1.4207 - val_PDOut_loss: 0.0801 - val_PPOut_loss: 0.6772 - val_ESCCOut_loss: 4.4324 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 138.3593 - val_BDOut_loss: 4.1384 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 182.6492 - val_MDOut_mean_absolute_error: 1.4207 - val_PDOut_mean_absolute_error: 0.0801 - val_PPOut_mean_absolute_error: 0.6772 - val_ESCCOut_mean_absolute_error: 4.4324 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 138.3593 - val_BDOut_mean_absolute_error: 4.1384
# Epoch 26/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 643.3781 - FSOut_loss: 307.5799 - KVOut_loss: 185.5156 - MDOut_loss: 1.4287 - PDOut_loss: 0.0468 - PPOut_loss: 0.6741 - ESCCOut_loss: 4.3584 - BCeOut_loss: 2.3281 - BCaOut_loss: 137.4139 - BDOut_loss: 4.0312 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 185.5156 - MDOut_mean_absolute_error: 1.4287 - PDOut_mean_absolute_error: 0.0468 - PPOut_mean_absolute_error: 0.6741 - ESCCOut_mean_absolute_error: 4.3584 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 137.4139 - BDOut_mean_absolute_error: 4.0312 - val_loss: 642.5737 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 182.7975 - val_MDOut_loss: 1.4028 - val_PDOut_loss: 0.0524 - val_PPOut_loss: 0.6659 - val_ESCCOut_loss: 4.4046 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 137.3840 - val_BDOut_loss: 4.1066 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 182.7975 - val_MDOut_mean_absolute_error: 1.4028 - val_PDOut_mean_absolute_error: 0.0524 - val_PPOut_mean_absolute_error: 0.6659 - val_ESCCOut_mean_absolute_error: 4.4046 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 137.3840 - val_BDOut_mean_absolute_error: 4.1066
# Epoch 27/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 641.8588 - FSOut_loss: 307.5799 - KVOut_loss: 184.9644 - MDOut_loss: 1.4250 - PDOut_loss: 0.0487 - PPOut_loss: 0.6705 - ESCCOut_loss: 4.3517 - BCeOut_loss: 2.3281 - BCaOut_loss: 136.4784 - BDOut_loss: 4.0107 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 184.9644 - MDOut_mean_absolute_error: 1.4250 - PDOut_mean_absolute_error: 0.0487 - PPOut_mean_absolute_error: 0.6705 - ESCCOut_mean_absolute_error: 4.3517 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 136.4784 - BDOut_mean_absolute_error: 4.0107 - val_loss: 641.0162 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 181.1939 - val_MDOut_loss: 1.4242 - val_PDOut_loss: 0.0446 - val_PPOut_loss: 0.6672 - val_ESCCOut_loss: 4.3989 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 137.5054 - val_BDOut_loss: 4.0220 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 181.1939 - val_MDOut_mean_absolute_error: 1.4242 - val_PDOut_mean_absolute_error: 0.0446 - val_PPOut_mean_absolute_error: 0.6672 - val_ESCCOut_mean_absolute_error: 4.3989 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 137.5054 - val_BDOut_mean_absolute_error: 4.0220
# Epoch 28/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 640.4803 - FSOut_loss: 307.5799 - KVOut_loss: 184.7452 - MDOut_loss: 1.4254 - PDOut_loss: 0.0459 - PPOut_loss: 0.6689 - ESCCOut_loss: 4.3320 - BCeOut_loss: 2.3281 - BCaOut_loss: 135.3611 - BDOut_loss: 3.9922 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 184.7452 - MDOut_mean_absolute_error: 1.4254 - PDOut_mean_absolute_error: 0.0459 - PPOut_mean_absolute_error: 0.6689 - ESCCOut_mean_absolute_error: 4.3320 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 135.3611 - BDOut_mean_absolute_error: 3.9922 - val_loss: 645.3663 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 183.4498 - val_MDOut_loss: 1.4333 - val_PDOut_loss: 0.0539 - val_PPOut_loss: 0.6628 - val_ESCCOut_loss: 4.4325 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 139.5720 - val_BDOut_loss: 4.0020 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 183.4498 - val_MDOut_mean_absolute_error: 1.4333 - val_PDOut_mean_absolute_error: 0.0539 - val_PPOut_mean_absolute_error: 0.6628 - val_ESCCOut_mean_absolute_error: 4.4325 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 139.5720 - val_BDOut_mean_absolute_error: 4.0020
# Epoch 29/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 639.1990 - FSOut_loss: 307.5799 - KVOut_loss: 184.6354 - MDOut_loss: 1.4260 - PDOut_loss: 0.0451 - PPOut_loss: 0.6652 - ESCCOut_loss: 4.3315 - BCeOut_loss: 2.3281 - BCaOut_loss: 134.2098 - BDOut_loss: 3.9769 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 184.6354 - MDOut_mean_absolute_error: 1.4260 - PDOut_mean_absolute_error: 0.0451 - PPOut_mean_absolute_error: 0.6652 - ESCCOut_mean_absolute_error: 4.3315 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 134.2098 - BDOut_mean_absolute_error: 3.9769 - val_loss: 642.8608 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 182.9368 - val_MDOut_loss: 1.4110 - val_PDOut_loss: 0.0425 - val_PPOut_loss: 0.6700 - val_ESCCOut_loss: 4.4378 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 137.5560 - val_BDOut_loss: 4.0470 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 182.9368 - val_MDOut_mean_absolute_error: 1.4110 - val_PDOut_mean_absolute_error: 0.0425 - val_PPOut_mean_absolute_error: 0.6700 - val_ESCCOut_mean_absolute_error: 4.4378 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 137.5560 - val_BDOut_mean_absolute_error: 4.0470
# Epoch 30/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 638.0861 - FSOut_loss: 307.5799 - KVOut_loss: 183.9698 - MDOut_loss: 1.4228 - PDOut_loss: 0.0445 - PPOut_loss: 0.6626 - ESCCOut_loss: 4.3274 - BCeOut_loss: 2.3281 - BCaOut_loss: 133.7922 - BDOut_loss: 3.9574 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 183.9698 - MDOut_mean_absolute_error: 1.4228 - PDOut_mean_absolute_error: 0.0445 - PPOut_mean_absolute_error: 0.6626 - ESCCOut_mean_absolute_error: 4.3274 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 133.7922 - BDOut_mean_absolute_error: 3.9574 - val_loss: 635.7532 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 180.4496 - val_MDOut_loss: 1.4070 - val_PDOut_loss: 0.0411 - val_PPOut_loss: 0.6641 - val_ESCCOut_loss: 4.4011 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 133.0572 - val_BDOut_loss: 3.9731 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 180.4496 - val_MDOut_mean_absolute_error: 1.4070 - val_PDOut_mean_absolute_error: 0.0411 - val_PPOut_mean_absolute_error: 0.6641 - val_ESCCOut_mean_absolute_error: 4.4011 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 133.0572 - val_BDOut_mean_absolute_error: 3.9731
# Epoch 31/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 637.5212 - FSOut_loss: 307.5799 - KVOut_loss: 184.0045 - MDOut_loss: 1.4245 - PDOut_loss: 0.0421 - PPOut_loss: 0.6626 - ESCCOut_loss: 4.3078 - BCeOut_loss: 2.3281 - BCaOut_loss: 133.2193 - BDOut_loss: 3.9509 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 184.0045 - MDOut_mean_absolute_error: 1.4245 - PDOut_mean_absolute_error: 0.0421 - PPOut_mean_absolute_error: 0.6626 - ESCCOut_mean_absolute_error: 4.3078 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 133.2193 - BDOut_mean_absolute_error: 3.9509 - val_loss: 641.7167 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 185.1655 - val_MDOut_loss: 1.4116 - val_PDOut_loss: 0.0421 - val_PPOut_loss: 0.6910 - val_ESCCOut_loss: 4.3576 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 134.3037 - val_BDOut_loss: 3.9851 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 185.1655 - val_MDOut_mean_absolute_error: 1.4116 - val_PDOut_mean_absolute_error: 0.0421 - val_PPOut_mean_absolute_error: 0.6910 - val_ESCCOut_mean_absolute_error: 4.3576 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 134.3037 - val_BDOut_mean_absolute_error: 3.9851
# Epoch 32/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 636.1622 - FSOut_loss: 307.5799 - KVOut_loss: 183.6123 - MDOut_loss: 1.4235 - PDOut_loss: 0.0420 - PPOut_loss: 0.6574 - ESCCOut_loss: 4.3170 - BCeOut_loss: 2.3281 - BCaOut_loss: 132.2594 - BDOut_loss: 3.9413 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 183.6123 - MDOut_mean_absolute_error: 1.4235 - PDOut_mean_absolute_error: 0.0420 - PPOut_mean_absolute_error: 0.6574 - ESCCOut_mean_absolute_error: 4.3170 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 132.2594 - BDOut_mean_absolute_error: 3.9413 - val_loss: 638.0815 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 183.4101 - val_MDOut_loss: 1.4256 - val_PDOut_loss: 0.0418 - val_PPOut_loss: 0.6672 - val_ESCCOut_loss: 4.5071 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 132.2230 - val_BDOut_loss: 4.0465 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 183.4101 - val_MDOut_mean_absolute_error: 1.4256 - val_PDOut_mean_absolute_error: 0.0418 - val_PPOut_mean_absolute_error: 0.6672 - val_ESCCOut_mean_absolute_error: 4.5071 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 132.2230 - val_BDOut_mean_absolute_error: 4.0465
# Epoch 33/100
# 1033/1033 [==============================] - 6s 6ms/step - loss: 635.4501 - FSOut_loss: 307.5799 - KVOut_loss: 183.1652 - MDOut_loss: 1.4243 - PDOut_loss: 0.0417 - PPOut_loss: 0.6565 - ESCCOut_loss: 4.3086 - BCeOut_loss: 2.3281 - BCaOut_loss: 132.0346 - BDOut_loss: 3.9097 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 183.1652 - MDOut_mean_absolute_error: 1.4243 - PDOut_mean_absolute_error: 0.0417 - PPOut_mean_absolute_error: 0.6565 - ESCCOut_mean_absolute_error: 4.3086 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 132.0346 - BDOut_mean_absolute_error: 3.9097 - val_loss: 640.0999 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 179.9724 - val_MDOut_loss: 1.4501 - val_PDOut_loss: 0.0437 - val_PPOut_loss: 0.6574 - val_ESCCOut_loss: 4.3733 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 137.8454 - val_BDOut_loss: 3.9975 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 179.9724 - val_MDOut_mean_absolute_error: 1.4501 - val_PDOut_mean_absolute_error: 0.0437 - val_PPOut_mean_absolute_error: 0.6574 - val_ESCCOut_mean_absolute_error: 4.3733 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 137.8454 - val_BDOut_mean_absolute_error: 3.9975
# Epoch 34/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 634.3614 - FSOut_loss: 307.5799 - KVOut_loss: 182.9505 - MDOut_loss: 1.4196 - PDOut_loss: 0.0410 - PPOut_loss: 0.6536 - ESCCOut_loss: 4.2872 - BCeOut_loss: 2.3281 - BCaOut_loss: 131.1834 - BDOut_loss: 3.9172 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 182.9505 - MDOut_mean_absolute_error: 1.4196 - PDOut_mean_absolute_error: 0.0410 - PPOut_mean_absolute_error: 0.6536 - ESCCOut_mean_absolute_error: 4.2872 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 131.1834 - BDOut_mean_absolute_error: 3.9172 - val_loss: 633.5195 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 179.2791 - val_MDOut_loss: 1.4212 - val_PDOut_loss: 0.0699 - val_PPOut_loss: 0.6490 - val_ESCCOut_loss: 4.3639 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 132.0438 - val_BDOut_loss: 3.9325 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 179.2791 - val_MDOut_mean_absolute_error: 1.4212 - val_PDOut_mean_absolute_error: 0.0699 - val_PPOut_mean_absolute_error: 0.6490 - val_ESCCOut_mean_absolute_error: 4.3639 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 132.0438 - val_BDOut_mean_absolute_error: 3.9325
# Epoch 35/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 634.1723 - FSOut_loss: 307.5799 - KVOut_loss: 182.9462 - MDOut_loss: 1.4192 - PDOut_loss: 0.0413 - PPOut_loss: 0.6527 - ESCCOut_loss: 4.2858 - BCeOut_loss: 2.3281 - BCaOut_loss: 131.0291 - BDOut_loss: 3.8895 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 182.9462 - MDOut_mean_absolute_error: 1.4192 - PDOut_mean_absolute_error: 0.0413 - PPOut_mean_absolute_error: 0.6527 - ESCCOut_mean_absolute_error: 4.2858 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 131.0291 - BDOut_mean_absolute_error: 3.8895 - val_loss: 636.7358 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 183.4150 - val_MDOut_loss: 1.4293 - val_PDOut_loss: 0.0409 - val_PPOut_loss: 0.6485 - val_ESCCOut_loss: 4.3935 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 131.1147 - val_BDOut_loss: 3.9339 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 183.4150 - val_MDOut_mean_absolute_error: 1.4293 - val_PDOut_mean_absolute_error: 0.0409 - val_PPOut_mean_absolute_error: 0.6485 - val_ESCCOut_mean_absolute_error: 4.3935 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 131.1147 - val_BDOut_mean_absolute_error: 3.9339
# Epoch 36/100
# 1033/1033 [==============================] - 7s 6ms/step - loss: 632.9788 - FSOut_loss: 307.5799 - KVOut_loss: 182.2123 - MDOut_loss: 1.4188 - PDOut_loss: 0.0411 - PPOut_loss: 0.6523 - ESCCOut_loss: 4.2731 - BCeOut_loss: 2.3281 - BCaOut_loss: 130.5865 - BDOut_loss: 3.8861 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 182.2123 - MDOut_mean_absolute_error: 1.4188 - PDOut_mean_absolute_error: 0.0411 - PPOut_mean_absolute_error: 0.6523 - ESCCOut_mean_absolute_error: 4.2731 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 130.5865 - BDOut_mean_absolute_error: 3.8861 - val_loss: 632.3378 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 179.7688 - val_MDOut_loss: 1.4005 - val_PDOut_loss: 0.0349 - val_PPOut_loss: 0.6481 - val_ESCCOut_loss: 4.3682 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 130.4143 - val_BDOut_loss: 3.9428 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 179.7688 - val_MDOut_mean_absolute_error: 1.4005 - val_PDOut_mean_absolute_error: 0.0349 - val_PPOut_mean_absolute_error: 0.6481 - val_ESCCOut_mean_absolute_error: 4.3682 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 130.4143 - val_BDOut_mean_absolute_error: 3.9428
# Epoch 37/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 632.5654 - FSOut_loss: 307.5799 - KVOut_loss: 182.1141 - MDOut_loss: 1.4188 - PDOut_loss: 0.0396 - PPOut_loss: 0.6499 - ESCCOut_loss: 4.2577 - BCeOut_loss: 2.3281 - BCaOut_loss: 130.3004 - BDOut_loss: 3.8755 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 182.1141 - MDOut_mean_absolute_error: 1.4188 - PDOut_mean_absolute_error: 0.0396 - PPOut_mean_absolute_error: 0.6499 - ESCCOut_mean_absolute_error: 4.2577 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 130.3004 - BDOut_mean_absolute_error: 3.8755 - val_loss: 631.9234 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 178.6753 - val_MDOut_loss: 1.4075 - val_PDOut_loss: 0.0894 - val_PPOut_loss: 0.6566 - val_ESCCOut_loss: 4.4715 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 130.8444 - val_BDOut_loss: 4.0187 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 178.6753 - val_MDOut_mean_absolute_error: 1.4075 - val_PDOut_mean_absolute_error: 0.0894 - val_PPOut_mean_absolute_error: 0.6566 - val_ESCCOut_mean_absolute_error: 4.4715 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 130.8444 - val_BDOut_mean_absolute_error: 4.0187
# Epoch 38/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 631.1472 - FSOut_loss: 307.5799 - KVOut_loss: 181.7367 - MDOut_loss: 1.4192 - PDOut_loss: 0.0403 - PPOut_loss: 0.6483 - ESCCOut_loss: 4.2557 - BCeOut_loss: 2.3281 - BCaOut_loss: 129.2599 - BDOut_loss: 3.8775 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 181.7367 - MDOut_mean_absolute_error: 1.4192 - PDOut_mean_absolute_error: 0.0403 - PPOut_mean_absolute_error: 0.6483 - ESCCOut_mean_absolute_error: 4.2557 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 129.2599 - BDOut_mean_absolute_error: 3.8775 - val_loss: 636.6730 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 178.4766 - val_MDOut_loss: 1.4329 - val_PDOut_loss: 0.0426 - val_PPOut_loss: 0.6448 - val_ESCCOut_loss: 4.2977 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 136.1403 - val_BDOut_loss: 3.8781 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 178.4766 - val_MDOut_mean_absolute_error: 1.4329 - val_PDOut_mean_absolute_error: 0.0426 - val_PPOut_mean_absolute_error: 0.6448 - val_ESCCOut_mean_absolute_error: 4.2977 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 136.1403 - val_BDOut_mean_absolute_error: 3.8781
# Epoch 39/100
# ...
# Epoch 89/100
# 1033/1033 [==============================] - 10s 10ms/step - loss: 612.6245 - FSOut_loss: 307.5799 - KVOut_loss: 172.7798 - MDOut_loss: 1.4014 - PDOut_loss: 0.0305 - PPOut_loss: 0.6052 - ESCCOut_loss: 3.7026 - BCeOut_loss: 2.3281 - BCaOut_loss: 120.5898 - BDOut_loss: 3.6066 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.7798 - MDOut_mean_absolute_error: 1.4014 - PDOut_mean_absolute_error: 0.0305 - PPOut_mean_absolute_error: 0.6052 - ESCCOut_mean_absolute_error: 3.7026 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 120.5898 - BDOut_mean_absolute_error: 3.6066 - val_loss: 613.0382 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 171.5579 - val_MDOut_loss: 1.3946 - val_PDOut_loss: 0.0313 - val_PPOut_loss: 0.6086 - val_ESCCOut_loss: 3.7905 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 120.1985 - val_BDOut_loss: 3.6969 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 171.5579 - val_MDOut_mean_absolute_error: 1.3946 - val_PDOut_mean_absolute_error: 0.0313 - val_PPOut_mean_absolute_error: 0.6086 - val_ESCCOut_mean_absolute_error: 3.7905 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 120.1985 - val_BDOut_mean_absolute_error: 3.6969
# Epoch 90/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 612.1587 - FSOut_loss: 307.5799 - KVOut_loss: 172.7500 - MDOut_loss: 1.3987 - PDOut_loss: 0.0299 - PPOut_loss: 0.6035 - ESCCOut_loss: 3.6914 - BCeOut_loss: 2.3281 - BCaOut_loss: 120.1837 - BDOut_loss: 3.5926 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.7500 - MDOut_mean_absolute_error: 1.3987 - PDOut_mean_absolute_error: 0.0299 - PPOut_mean_absolute_error: 0.6035 - ESCCOut_mean_absolute_error: 3.6914 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 120.1837 - BDOut_mean_absolute_error: 3.5926 - val_loss: 623.7832 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 180.5399 - val_MDOut_loss: 1.3783 - val_PDOut_loss: 0.0288 - val_PPOut_loss: 0.6190 - val_ESCCOut_loss: 3.8234 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 121.9659 - val_BDOut_loss: 3.6677 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 180.5399 - val_MDOut_mean_absolute_error: 1.3783 - val_PDOut_mean_absolute_error: 0.0288 - val_PPOut_mean_absolute_error: 0.6190 - val_ESCCOut_mean_absolute_error: 3.8234 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 121.9659 - val_BDOut_mean_absolute_error: 3.6677
# Epoch 91/100
# 1033/1033 [==============================] - 9s 9ms/step - loss: 611.6480 - FSOut_loss: 307.5799 - KVOut_loss: 172.6340 - MDOut_loss: 1.3966 - PDOut_loss: 0.0298 - PPOut_loss: 0.6048 - ESCCOut_loss: 3.6619 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.8286 - BDOut_loss: 3.5833 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.6340 - MDOut_mean_absolute_error: 1.3966 - PDOut_mean_absolute_error: 0.0298 - PPOut_mean_absolute_error: 0.6048 - ESCCOut_mean_absolute_error: 3.6619 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.8286 - BDOut_mean_absolute_error: 3.5833 - val_loss: 618.5798 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 170.3423 - val_MDOut_loss: 1.3938 - val_PDOut_loss: 0.0284 - val_PPOut_loss: 0.6149 - val_ESCCOut_loss: 3.8213 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 126.9468 - val_BDOut_loss: 3.6720 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 170.3423 - val_MDOut_mean_absolute_error: 1.3938 - val_PDOut_mean_absolute_error: 0.0284 - val_PPOut_mean_absolute_error: 0.6149 - val_ESCCOut_mean_absolute_error: 3.8213 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 126.9468 - val_BDOut_mean_absolute_error: 3.6720
# Epoch 92/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 611.2880 - FSOut_loss: 307.5799 - KVOut_loss: 172.3478 - MDOut_loss: 1.3961 - PDOut_loss: 0.0296 - PPOut_loss: 0.6013 - ESCCOut_loss: 3.6710 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.7535 - BDOut_loss: 3.5798 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.3478 - MDOut_mean_absolute_error: 1.3961 - PDOut_mean_absolute_error: 0.0296 - PPOut_mean_absolute_error: 0.6013 - ESCCOut_mean_absolute_error: 3.6710 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.7535 - BDOut_mean_absolute_error: 3.5798 - val_loss: 611.0955 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 171.3620 - val_MDOut_loss: 1.4187 - val_PDOut_loss: 0.0314 - val_PPOut_loss: 0.6139 - val_ESCCOut_loss: 3.7247 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 118.5280 - val_BDOut_loss: 3.6568 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 171.3620 - val_MDOut_mean_absolute_error: 1.4187 - val_PDOut_mean_absolute_error: 0.0314 - val_PPOut_mean_absolute_error: 0.6139 - val_ESCCOut_mean_absolute_error: 3.7247 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 118.5280 - val_BDOut_mean_absolute_error: 3.6568
# Epoch 93/100
# 1033/1033 [==============================] - 9s 8ms/step - loss: 611.0730 - FSOut_loss: 307.5799 - KVOut_loss: 172.2116 - MDOut_loss: 1.3969 - PDOut_loss: 0.0300 - PPOut_loss: 0.6027 - ESCCOut_loss: 3.6505 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.6983 - BDOut_loss: 3.5735 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.2116 - MDOut_mean_absolute_error: 1.3969 - PDOut_mean_absolute_error: 0.0300 - PPOut_mean_absolute_error: 0.6027 - ESCCOut_mean_absolute_error: 3.6505 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.6983 - BDOut_mean_absolute_error: 3.5735 - val_loss: 617.3812 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 172.0723 - val_MDOut_loss: 1.3991 - val_PDOut_loss: 0.0291 - val_PPOut_loss: 0.6059 - val_ESCCOut_loss: 3.7899 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 124.0407 - val_BDOut_loss: 3.6841 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 172.0723 - val_MDOut_mean_absolute_error: 1.3991 - val_PDOut_mean_absolute_error: 0.0291 - val_PPOut_mean_absolute_error: 0.6059 - val_ESCCOut_mean_absolute_error: 3.7899 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 124.0407 - val_BDOut_mean_absolute_error: 3.6841
# Epoch 94/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 610.9082 - FSOut_loss: 307.5799 - KVOut_loss: 172.1255 - MDOut_loss: 1.3937 - PDOut_loss: 0.0290 - PPOut_loss: 0.6011 - ESCCOut_loss: 3.6349 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.6282 - BDOut_loss: 3.5857 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.1255 - MDOut_mean_absolute_error: 1.3937 - PDOut_mean_absolute_error: 0.0290 - PPOut_mean_absolute_error: 0.6011 - ESCCOut_mean_absolute_error: 3.6349 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.6282 - BDOut_mean_absolute_error: 3.5857 - val_loss: 611.2670 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 170.8858 - val_MDOut_loss: 1.3916 - val_PDOut_loss: 0.0275 - val_PPOut_loss: 0.6167 - val_ESCCOut_loss: 3.7172 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 119.2211 - val_BDOut_loss: 3.6471 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 170.8858 - val_MDOut_mean_absolute_error: 1.3916 - val_PDOut_mean_absolute_error: 0.0275 - val_PPOut_mean_absolute_error: 0.6167 - val_ESCCOut_mean_absolute_error: 3.7172 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 119.2211 - val_BDOut_mean_absolute_error: 3.6471
# Epoch 95/100
# 1033/1033 [==============================] - 9s 9ms/step - loss: 610.5331 - FSOut_loss: 307.5799 - KVOut_loss: 171.7070 - MDOut_loss: 1.3991 - PDOut_loss: 0.0298 - PPOut_loss: 0.6023 - ESCCOut_loss: 3.6367 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.6661 - BDOut_loss: 3.5824 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 171.7070 - MDOut_mean_absolute_error: 1.3991 - PDOut_mean_absolute_error: 0.0298 - PPOut_mean_absolute_error: 0.6023 - ESCCOut_mean_absolute_error: 3.6367 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.6661 - BDOut_mean_absolute_error: 3.5824 - val_loss: 612.5400 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 171.2807 - val_MDOut_loss: 1.3776 - val_PDOut_loss: 0.0264 - val_PPOut_loss: 0.6079 - val_ESCCOut_loss: 3.6952 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 120.1042 - val_BDOut_loss: 3.6881 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 171.2807 - val_MDOut_mean_absolute_error: 1.3776 - val_PDOut_mean_absolute_error: 0.0264 - val_PPOut_mean_absolute_error: 0.6079 - val_ESCCOut_mean_absolute_error: 3.6952 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 120.1042 - val_BDOut_mean_absolute_error: 3.6881
# Epoch 96/100
# 1033/1033 [==============================] - 7s 7ms/step - loss: 610.4639 - FSOut_loss: 307.5799 - KVOut_loss: 172.0050 - MDOut_loss: 1.3934 - PDOut_loss: 0.0295 - PPOut_loss: 0.6006 - ESCCOut_loss: 3.6205 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.3425 - BDOut_loss: 3.5633 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 172.0050 - MDOut_mean_absolute_error: 1.3934 - PDOut_mean_absolute_error: 0.0295 - PPOut_mean_absolute_error: 0.6006 - ESCCOut_mean_absolute_error: 3.6205 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.3425 - BDOut_mean_absolute_error: 3.5633 - val_loss: 617.8224 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 178.5733 - val_MDOut_loss: 1.3775 - val_PDOut_loss: 0.0316 - val_PPOut_loss: 0.6066 - val_ESCCOut_loss: 3.7343 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 118.0531 - val_BDOut_loss: 3.6860 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 178.5733 - val_MDOut_mean_absolute_error: 1.3775 - val_PDOut_mean_absolute_error: 0.0316 - val_PPOut_mean_absolute_error: 0.6066 - val_ESCCOut_mean_absolute_error: 3.7343 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 118.0531 - val_BDOut_mean_absolute_error: 3.6860
# Epoch 97/100
# 1033/1033 [==============================] - 9s 9ms/step - loss: 609.9384 - FSOut_loss: 307.5799 - KVOut_loss: 171.4576 - MDOut_loss: 1.3962 - PDOut_loss: 0.0294 - PPOut_loss: 0.5997 - ESCCOut_loss: 3.6115 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.3752 - BDOut_loss: 3.5594 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 171.4576 - MDOut_mean_absolute_error: 1.3962 - PDOut_mean_absolute_error: 0.0294 - PPOut_mean_absolute_error: 0.5997 - ESCCOut_mean_absolute_error: 3.6115 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.3752 - BDOut_mean_absolute_error: 3.5594 - val_loss: 611.1066 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 169.0315 - val_MDOut_loss: 1.4219 - val_PDOut_loss: 0.0474 - val_PPOut_loss: 0.6034 - val_ESCCOut_loss: 3.7737 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 120.8146 - val_BDOut_loss: 3.6540 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 169.0315 - val_MDOut_mean_absolute_error: 1.4219 - val_PDOut_mean_absolute_error: 0.0474 - val_PPOut_mean_absolute_error: 0.6034 - val_ESCCOut_mean_absolute_error: 3.7737 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 120.8146 - val_BDOut_mean_absolute_error: 3.6540
# Epoch 98/100
# 1033/1033 [==============================] - 9s 9ms/step - loss: 609.9857 - FSOut_loss: 307.5799 - KVOut_loss: 171.6246 - MDOut_loss: 1.4025 - PDOut_loss: 0.0292 - PPOut_loss: 0.5985 - ESCCOut_loss: 3.5950 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.2608 - BDOut_loss: 3.5661 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 171.6246 - MDOut_mean_absolute_error: 1.4025 - PDOut_mean_absolute_error: 0.0292 - PPOut_mean_absolute_error: 0.5985 - ESCCOut_mean_absolute_error: 3.5950 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.2608 - BDOut_mean_absolute_error: 3.5661 - val_loss: 611.0830 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 168.7072 - val_MDOut_loss: 1.3762 - val_PDOut_loss: 0.0256 - val_PPOut_loss: 0.6064 - val_ESCCOut_loss: 3.7958 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 121.1391 - val_BDOut_loss: 3.6728 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 168.7072 - val_MDOut_mean_absolute_error: 1.3762 - val_PDOut_mean_absolute_error: 0.0256 - val_PPOut_mean_absolute_error: 0.6064 - val_ESCCOut_mean_absolute_error: 3.7958 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 121.1391 - val_BDOut_mean_absolute_error: 3.6728
# Epoch 99/100
# 1033/1033 [==============================] - 8s 8ms/step - loss: 610.1033 - FSOut_loss: 307.5799 - KVOut_loss: 171.4853 - MDOut_loss: 1.3971 - PDOut_loss: 0.0290 - PPOut_loss: 0.6002 - ESCCOut_loss: 3.5749 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.5383 - BDOut_loss: 3.5692 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 171.4853 - MDOut_mean_absolute_error: 1.3971 - PDOut_mean_absolute_error: 0.0290 - PPOut_mean_absolute_error: 0.6002 - ESCCOut_mean_absolute_error: 3.5749 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.5383 - BDOut_mean_absolute_error: 3.5692 - val_loss: 608.3548 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 168.5468 - val_MDOut_loss: 1.3816 - val_PDOut_loss: 0.0303 - val_PPOut_loss: 0.6027 - val_ESCCOut_loss: 3.7092 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 118.6654 - val_BDOut_loss: 3.6588 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 168.5468 - val_MDOut_mean_absolute_error: 1.3816 - val_PDOut_mean_absolute_error: 0.0303 - val_PPOut_mean_absolute_error: 0.6027 - val_ESCCOut_mean_absolute_error: 3.7092 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 118.6654 - val_BDOut_mean_absolute_error: 3.6588
# Epoch 100/100
# 1033/1033 [==============================] - 8s 7ms/step - loss: 609.2844 - FSOut_loss: 307.5799 - KVOut_loss: 171.0534 - MDOut_loss: 1.3952 - PDOut_loss: 0.0293 - PPOut_loss: 0.6004 - ESCCOut_loss: 3.5757 - BCeOut_loss: 2.3281 - BCaOut_loss: 119.1607 - BDOut_loss: 3.5599 - FSOut_mean_absolute_error: 307.5799 - KVOut_mean_absolute_error: 171.0534 - MDOut_mean_absolute_error: 1.3952 - PDOut_mean_absolute_error: 0.0293 - PPOut_mean_absolute_error: 0.6004 - ESCCOut_mean_absolute_error: 3.5757 - BCeOut_mean_absolute_error: 2.3281 - BCaOut_mean_absolute_error: 119.1607 - BDOut_mean_absolute_error: 3.5599 - val_loss: 621.3619 - val_FSOut_loss: 309.4252 - val_KVOut_loss: 177.4270 - val_MDOut_loss: 1.3971 - val_PDOut_loss: 0.0298 - val_PPOut_loss: 0.6039 - val_ESCCOut_loss: 3.6911 - val_BCeOut_loss: 2.3357 - val_BCaOut_loss: 122.8133 - val_BDOut_loss: 3.6396 - val_FSOut_mean_absolute_error: 309.4252 - val_KVOut_mean_absolute_error: 177.4270 - val_MDOut_mean_absolute_error: 1.3971 - val_PDOut_mean_absolute_error: 0.0298 - val_PPOut_mean_absolute_error: 0.6039 - val_ESCCOut_mean_absolute_error: 3.6911 - val_BCeOut_mean_absolute_error: 2.3357 - val_BCaOut_mean_absolute_error: 122.8133 - val_BDOut_mean_absolute_error: 3.6396

# %%
# Define Test Prediction 
testPred = model.predict(normTestIn)

# Load Predicted Input
dataLoc2 = '[REDACTED]'
# Read in dataset
predictdf = pd.read_csv(dataLoc2)

# Normalise data
predictNorm = np.array(normalise(predictdf))

# Make Prediction
predictList = model.predict(predictNorm)
# Out:
# 323/323 [==============================] - 1s 3ms/step
# [array([[0.01759833, 0.12687005, 0.1965328 , ..., 0.01549755, 0.45136607,
#         0.01101177],
#        [0.0336727 , 0.1432136 , 0.18272   , ..., 0.02632677, 0.40910935,
#         0.01314119],
#        [0.03356735, 0.14596044, 0.18472522, ..., 0.02604037, 0.39975753,
#         0.01352021],
#        ...,
#        [0.09688378, 0.04545205, 0.03738395, ..., 0.08455106, 0.01247144,
#         0.4216633 ],
#        [0.09769194, 0.02982935, 0.03309954, ..., 0.13368201, 0.02057289,
#         0.4188076 ],
#        [0.07920932, 0.03450161, 0.04338666, ..., 0.12419632, 0.03079072,
#         0.38915905]], dtype=float32), array([[3854.3394 ],
#        [3650.675  ],
#        [3582.4983 ],
#        ...,
#        [ 617.3662 ],
#        [ 957.44086],
#        [ 923.39856]], dtype=float32), array([[ 9.808435],
#        [ 9.808717],
#        [ 9.812583],
#        ...,
#        [27.782389],
#        [27.688576],
#        [27.8787  ]], dtype=float32), array([[ 3.0010335],
#        [ 2.9989126],
#        [ 2.9996161],
#        ...,
#        [10.99573  ],
#        [11.002753 ],
#        [10.979651 ]], dtype=float32), array([[7.4759297],
#        [7.523769 ],
#        [7.3218865],
#        ...,
#        [2.9200902],
#        [2.1757278],
#        [1.9339304]], dtype=float32), array([[ 9.769185],
#        [ 9.623238],
#        [ 9.726112],
#        ...,
#        [36.64864 ],
#        [37.53209 ],
#        [39.69371 ]], dtype=float32), array([[9.9964428e-01, 2.3134555e-11, 3.5568504e-04],
#        [9.9941099e-01, 7.4758804e-09, 5.8905530e-04],
#        [9.9934167e-01, 1.0140087e-08, 6.5827853e-04],
#        ...,
#        [3.4825694e-11, 9.9999994e-01, 7.1217192e-09],
#        [1.4367612e-07, 9.9999398e-01, 5.7831644e-06],
#        [6.7603018e-05, 9.9896312e-01, 9.6927909e-04]], dtype=float32), array([[ 504.6127 ],
#        [ 521.0476 ],
#        [ 517.43024],
#        ...,
#        [3971.1218 ],
#        [3839.542  ],
#        [3745.2576 ]], dtype=float32), array([[10.131268 ],
#        [10.0795355],
#        [10.049605 ],
#        ...,
#        [37.522007 ],
#        [38.9964   ],
#        [40.25923  ]], dtype=float32)]
